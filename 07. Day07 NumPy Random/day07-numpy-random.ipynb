# %% [markdown]
# **Numpy Random** --by Punith V T

# %%
from numpy import random

x1 = random.rand()  # rand() method returns random float between 0 and 1.
x2 = random.rand(5)  # Generate a 1-D array containing 5 random floats.
x3 = random.choice([30, 50, 70, 90])   # The choice() method allows you to generate a random value based on an array values
x4 = random.choice([3, 5, 7, 9], size=(3, 5))  # It Add a size parameter to specify the shape of the array.
x5 = random.randint(100)  # Generate a random integer from 0 to 100.

print(x1)
print(x2)
print(x3)
print(x4)
print(x5)
# Out:
# 0.043169318830413084
# [8.48762561e-01 9.81120124e-01 8.50155692e-01 7.17871781e-01
#  2.54612869e-04]
# 70
# [[5 9 9 9 7]
#  [7 9 9 9 3]
#  [5 3 5 9 3]]
# 55

# %% [markdown]
# **Normal Distribution** (Gaussian)

# %%
from numpy import random

y1 = random.normal(loc=1, scale=2, size=(2, 3))
y2 = random.binomial(n=10, p=0.5, size=10)
y3 = random.poisson(lam=2, size=10)
y4 = random.uniform(size=(3, 3))
y5 = random.logistic(loc=1, scale=2, size=(2, 3))

print(y1)
print("-------")
print(y2)
print("-------")
print(y3)
print("-------")
print(y4)
print("-------")
print(y5)
# Out:
# [[ 0.13493765  0.8184753   1.47022853]
#  [-1.83364002  1.48111144  0.13138696]]
# -------
# [4 2 5 4 5 4 4 8 4 3]
# -------
# [3 4 6 1 2 3 3 1 2 1]
# -------
# [[0.75416582 0.87905556 0.22177386]
#  [0.06036103 0.31979078 0.13864841]
#  [0.89534273 0.24370535 0.10513508]]
# -------
# [[ 0.18872577 -2.93092479 -2.17470362]
#  [ 0.57339708 -4.75382704  1.41750237]]

# %% [markdown]
# V**isualization of Distribution**

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Create subplots to display the distributions using Seaborn
plt.figure(figsize=(15,15))

# Normal distribution
plt.subplot(331)
sns.distplot(random.normal(size=1000), hist=False)
plt.title('Normal Distribution')

# Binomial distribution
plt.subplot(332)
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
plt.title('Binomial Distribution')

# Poisson distribution
plt.subplot(333)
sns.distplot(random.poisson(lam=2, size=1000), kde=True)
plt.title('Poisson distribution')
# Out:
# /tmp/ipykernel_33/987842292.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_33/987842292.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
# /tmp/ipykernel_33/987842292.py:16: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=2, size=1000), kde=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Poisson distribution')

# %% [markdown]
# **NumPy Universal Functions**

# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4, 5, 6])
arr2 = np.array([20, 21, 22, 23, 24, 25])

new1 = np.add(arr1, arr2)
new2 = np.subtract(arr1, arr2)
new3 = np.multiply(arr1, arr2)
new4 = np.divide(arr1, arr2)
new5 = np.power(arr1, arr2)
new6 = np.mod(arr1, arr2)
new7 = np.remainder(arr1, arr2)

print(new1)
print("-------")
print(new2)
print("-------")
print(new3)
print("-------")
print(new4)
print("-------")
print(new5)
print("-------")
print(new6)
print("-------")
print(new7)
# Out:
# [21 23 25 27 29 31]
# -------
# [-19 -19 -19 -19 -19 -19]
# -------
# [ 20  42  66  92 120 150]
# -------
# [0.05       0.0952381  0.13636364 0.17391304 0.20833333 0.24      ]
# -------
# [                   1              2097152          31381059609
#        70368744177664    59604644775390625 -8463200117489401856]
# -------
# [1 2 3 4 5 6]
# -------
# [1 2 3 4 5 6]

# %%
import numpy as np

arr = np.array([-10, -20, 10, 20, 30, -40])
new = np.absolute(arr)

print(new)
# Out:
# [10 20 10 20 30 40]

# %% [markdown]
# **Rounding Decimals**

# %%
#ways of rounding decimals
arr1 = np.fix([-3.1786, 3.6667])
arr2 = np.around(3.1996, 2)
arr3 = np.floor([-3.1966, 3.6667])
arr4 = np.ceil([-3.1566, 3.6667])

print(arr1)
print(arr2)
print(arr3)
print(arr4)
# Out:
# [-3.  3.]
# 3.2
# [-4.  3.]
# [-3.  4.]
